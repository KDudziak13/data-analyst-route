# %%
##przyklady
str= "tekst"
int= 42 #liczby
float = 42.00 #z miejscami po przecinku

slowo1 = "hello"
slowo2 = "world"
# Out:
# hello world

# %%
##laczenie stringow, konkatenacja
zdanie = slowo1+ " "+ slowo2
print(zdanie)

# %%
mnozenie = slowo2 *3
print(mnozenie)

mnozenie_advanced = (slowo2 +" ")*3
print(mnozenie_advanced)
# Out:
# worldworldworld
# world world world

# %%
#poszczegolne litery
text = "Python"

# Indeksy
print(text[0])   # "P"
print(text[-1])  # "n" (ostatni znak)

# Slicing
print(text[0:4])   # "Pyth" (od 0 do 3)
print(text[2:])    # "thon" (od 2 do końca)
print(text[:3])    # "Pyt" (od początku do 2)
print(text[::2])   # "Pto" (co drugi znak)
# Out:
# P
# n
# Pyth
# thon
# Pyt
# Pto

# %%
##dlugosc
print(len(mnozenie_advanced))
# Out:
# 18

# %%
##czy dana litera wystepuje
s = "Python"

print("P" in s)   # True
print("Java" not in s)  # True
print("r" in s)   # True
# Out:
# True
# True
# False

# %%
s = "  Python Programming  "

# Usuwanie białych znaków
print(s.strip())   # "Python Programming"

# Zmiana wielkości liter
print(s.upper())   # "  PYTHON PROGRAMMING  "
print(s.lower())   # "  python programming  "
print(s.title())   # "  Python Programming  "

# Zamiana tekstu
print(s.replace("Python", "Java"))  # "  Java Programming  "

# Podział na listę
print(s.split())  # ["Python", "Programming"]

# Łączenie listy w string
words = ["Python", "is", "fun"]
print(" ".join(words))  # "Python is fun"
# Out:
# Python Programming
#   PYTHON PROGRAMMING
#   python programming
#   Python Programming
#   Java Programming
# ['Python', 'Programming']
# Python is fun

# %% [markdown]
# Część 1:
#
# Tworzenie i drukowanie stringów
#
# Utwórz zmienną s zawierającą tekst "Python jest fajny" i wyświetl ją na ekranie.

# %%
zmienna= "Python jest fajny"
print(zmienna)
# Out:
# Python jest fajny

# %% [markdown]
# Łączenie stringów
#
# Utwórz dwie zmienne: first_name = "Jan" i last_name = "Kowalski". Połącz je w jeden string w formacie "Jan Kowalski" i wyświetl wynik.

# %%
first_name="Jan"
last_name="Kowalski"

calosc= first_name+" "+ last_name
print(calosc)
# Out:
# Jan Kowalski

# %% [markdown]
# Powielanie stringów
#
# Utwórz zmienną laugh = "Ha" i wyświetl ją powtórzoną 5 razy w jednej linii.
#
# Oczekiwany wynik:

# %%
str1="Ha"
print(str1*5)
# Out:
# HaHaHaHaHa

# %% [markdown]
# Długość stringa
#
# Sprawdź długość stringa "Hello, World!" i wyświetl wynik.

# %%
print(len("Hello world"))
# Out:
# 11

# %% [markdown]
# Część 2: Indeksowanie i slicing
#
# Indeksy
#
# Dla stringa s = "Python":
#
# Wyświetl pierwszy znak
#
# Wyświetl ostatni znak
#
# Wyświetl przedostatni znak

# %%
s="Python"
print(len(s))
# Out:
# 6

# %%
print("1. znak")
print(s[0])

print("ostatni znak")
print(s[-1])

print("przedostatni znak")
print(s[-2])
# Out:
# 1. znak
# P
# ostatni znak
# n
# przedostatni znak
# o

# %% [markdown]
# Slicing
#
# Dla stringa s = "PythonProgramming":
#
# Wyświetl "Python"
#
# Wyświetl "Programming"
#
# Wyświetl co drugi znak całego stringa
#
# Odwróć string i wyświetl wynik

# %%
s = "PythonProgramming"
print("co drugi znak")
print(s[::2])

print("odwroc string")
print(s[::-1])

print("wyswietl python")
print(s[:-11])

print("wyswietl programming")
print(s[:6])
# Out:
# co drugi znak
# PtoPormig
# odwroc string
# gnimmargorPnohtyP
# wyswietl python
# Python
# wyswietl programming
# Python

# %% [markdown]
# Część 3: Metody stringów
#
# Zmiana wielkości liter
#
# Dla stringa "python jest super":
#
# Zamień na wielkie litery
#
# Zamień na tytułowe litery (każde słowo zaczyna się od wielkiej litery)

# %%
s="python jest super"
print(s.upper())
# Out:
# PYTHON JEST SUPER

# %%
print("Zamień na tytułowe litery (każde słowo zaczyna się od wielkiej litery")
s="python jest super"
print(s.title())
# Out:
# Zamień na tytułowe litery (każde słowo zaczyna się od wielkiej litery
# Python Jest Super

# %% [markdown]
# Usuwanie spacji
#
# Dla stringa " Python " usuń spacje z początku i końca.

# %%
from os import remove
s=" Python "
print(s)
print(s.strip())
# Out:
#  Python
# Python

# %% [markdown]
# Zamiana i wyszukiwanie
#
# Dla stringa "Ala ma kota":
#
# Zamień "Ala" na "Ola"
#
# Sprawdź, czy "kota" występuje w stringu
#
# Policz ile razy występuje litera "a"

# %%
s = "Ala ma kota"
s = s.replace("Ala", "Ola")
print(s)

s1 = s.count("a")
print(s1)

if "kota" in s:
  print("tak")
else:
  print("nie")
# Out:
# Ola ma kota
# 3
# tak

# %%
Podział i łączenie stringów

Dla stringa "Python jest fajny" podziel go na listę słów

Następnie połącz listę z powrotem w string, używając przecinka , jako separatora

# %%
s = "Python jest fajny"
m = s.split()
print(m)
m1 = ",".join(m)
print(m1)
# Out:
# ['Python', 'jest', 'fajny']
# Python,jest,fajny

# %% [markdown]
# Część 4: Formatowanie stringów
#
# f-stringi
#
# Utwórz zmienne: name = "Anna", age = 30
#
# Wyświetl zdanie: "Anna ma 30 lat" używając f-stringów
#
# format()

# %%
name = "Anna"
age = 30
print(f"{name} ma {age} lat")
# Out:
# Anna ma 30 lat

# %% [markdown]
# Zrób to samo co wyżej, używając metody .format()
#
# Stary styl %
#
# Zrób to samo, używając operatora %

# %%
tekst = "Mam na imie {} i mam {} lat"
wynik = tekst.format(name, age)
print(wynik)
# Out:
# Mam na imie Anna i mam 30 lat

# %% [markdown]
# Dla stringa "PythonProgramming":
#
# Sprawdź, czy zaczyna się od "Python"
#
# Sprawdź, czy kończy się na "Script"
#
# Liczba znaków i odwracanie słów
#
# Dla stringa "Python jest fajny":
#
# Policz liczbę znaków w stringu
#
# Odwróć kolejność słów (ma być "fajny jest Python")
#
# ---

# %%
s= "PythonProgramming"
print(s.startswith("python"))
print(s.startswith("Python"))
print(s.endswith("Programming"))
slowa = len(s)
print(slowa)
# Out:
# False
# True
# True
# 17

# %% [markdown]
# Łączenie listy słów
#
# Dla listy words = ["Python", "jest", "super"] połącz słowa w string, używając spacji i wyświetl wynik.

# %%
arg = ["Python", "jest", "super"]
def lista(elements):
  w = " ".join(elements)
  print(w)

lista(arg)

reversed_text = arg.reverse()
print(" ".join(arg))
# Out:
# Python jest super
# super jest Python

# %% [markdown]
# 💡 Opcjonalne dodatkowe wyzwanie:
#
# Napisz funkcję, która otrzymuje string i zwraca:
#
# Liczbę samogłosek
#
# Liczbę spółgłosek
#
# Odwrócony string

# %%
string = "Ala ma kota"


def odwrot(l):
  count = 0
  count1 = 0

  for letter in l:
    if letter.isalpha():
      if letter in "aeiouAEIOU":
        count+=1
      else:
        count1+=1
  print("samogloski")
  print(count)
  print("spolgloski")
  print(count1)




odwrot(string)
# Out:
# samogloski
# 5
# spolgloski
# 4
